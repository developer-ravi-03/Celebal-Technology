# %% [markdown]
# # Week 3 Assignment
#
# ## Objective
#
# Analyze Superstore dataset using:
# - Subqueries
# - CTEs
# - Window Functions
#
# ## Dataset Import
#
# Dataset imported into MySQL table:
# superstore_raw
#
# ## Tables Created
#
# - customers
# - products
# - orders
#
# ## Subqueries
#
# Query 1:
# Orders with sales greater than average sales.
#
# Query 2:
# Highest sales order for each customer.
#
# ## CTE Queries
#
# Query 3:
# Total sales for each customer.
#
# Query 4:
# Customers whose sales are above average.
#
# ## Window Functions
#
# Query 5:
# Customer ranking.
#
# Query 6:
# Row number for each order.
#
# Query 7:
# Top 3 customers.
#
# ## Final Query
#
# Customer Name
# Total Sales
# Rank
#
# ## Mini Project
#
# Top Customers
#
# Bottom Customers
#
# Single Order Customers
#
# Above Average Customers
#
# Highest Order Per Customer
#
# ## Insights
#
# 1. A small number of customers generate most of the revenue.
#
# 2. Window functions make ranking and ordering much easier.
#
# 3. CTEs improve query readability.
#
# 4. Subqueries are useful for comparison-based analysis.
#
# 5. Customer sales vary significantly across the dataset.
